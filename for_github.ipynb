# %%
to_run = True
if to_run:
  # !git clone https://github.com/nackta/text_classification.git # your path /content/drive/
  # %cd text_classification
  to_run = False
  # !wandb login
# Out:
# fatal: destination path 'text_classification' already exists and is not an empty directory.
# /content/text_classification
